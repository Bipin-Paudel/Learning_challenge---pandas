# %% [markdown]
# # Interpolate

# %%
import pandas as pd

# %%
var = pd.read_csv("C:\\Users\\Vipin\\pandas_challenge\\customers-100.csv")
var
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade                NaN
# ..                              ...                ...
# ...

# %%
var.interpolate() # it doesn't work with alphabet
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\2087475351.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate() # it doesn't work with alphabet
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# ...

# %%
var.interpolate(method="linear" )
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\906631510.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(method="linear")
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# ...

# %%
var.interpolate(method="linear" ,axis=0)  # if axis=1 it deals with rowwise
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\2052004176.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(method="linear" ,axis=0)  # if axis=1 it deals with rowwise
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# ...

# %%
var.interpolate(limit=2)
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\545238221.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit=2)
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# ...

# %%
var.interpolate(limit_direction="forward", limit=3) # also both and backward are exists
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\1720319508.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit_direction="forward", limit=3)
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# ...

# %%
var.interpolate(limit_area='inside') # outside also exist to not fill
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\674275558.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit_area='inside') # outside also exist to not fill
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# ...

# %%
var.interpolate(limit_direction='both',limit=2, inplace=True)
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_9828\1749376285.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit_direction='both',limit=2, inplace=True)
