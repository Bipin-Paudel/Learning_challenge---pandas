# %% [markdown]
# # Replace

# %%
import pandas as pd
var_1 = pd.read_csv("C:\\Users\\Vipin\\pandas_challenge\\customers-100.csv")
var_1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
var_1.replace(to_replace=1,value=14)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0    14.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
var_1.replace(to_replace='Roy',value="Bipin")
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6      Bipin     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
var_1.replace([1,2,3,4,5,6,7,8,9],25)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0    25.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1    25.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2    25.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4    25.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
var_1.replace("[A-Za-z]","python", regex=True)
# Out:
#     Index                                        Customer Id  \
# 0     1.0  pythonpython37pythonpython93pythonpythonpython...
# 1     2.0  1pythonpython7python82python4pythonpythonpytho...
# 2     3.0  6python94879pythonpythonpythonpythonpython5pyt...
# 3     NaN  5pythonpythonpython8pythonpythonpython16python...
# 4     5.0                053python585pythonpython6python3159
# ..    ...                                                ...
# 95   96.0  pythonpython8python23python48python22pythonpyt...
# 96   97.0  pythonpythonpython220pythonpythonpythonpythonp...
# 97   98.0  28pythonpythonpythonpython0pythonpythonpython4...
# 98   99.0  python23python1python9pythonpython8pythonpytho...
# 99  100.0                2354python0python336python91python1
#
#                                           First Name  \
# 0               pythonpythonpythonpythonpythonpython
# 1         pythonpythonpythonpythonpythonpythonpython
# 2                                 pythonpythonpython
# ...

# %%
var_1.replace({"SYMBOL":'[A-Z]'},22, regex=True)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
var_1.replace(1, method="ffill")
var_1
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_7012\2206157770.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var_1.replace(1, method="ffill")
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# ...

# %%
var_1.replace(1, method="bfill")
var_1
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_7012\2829973312.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var_1.replace(1, method="bfill")
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy     Berry
# 3     NaN  5Cef8BFA16c5e3c      Linda     Olsen
# 4     5.0  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# ...

# %%
var_1.replace(1, method="bfill", limit=2, inplace=True)
# Out:
# C:\Users\Vipin\AppData\Local\Temp\ipykernel_7012\3947900734.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var_1.replace(1, method="bfill", limit=2, inplace=True)
